# %% [markdown]
# #💡Heart_disease Dataset

# %% [markdown]
# #**🔍  General Data Exploration**

# %% [markdown]
# ❓Q. How to load the dataset.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('heart_disease.csv')

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ❓Q. What are the basic details of the dataset? (rows, columns)

# %%
df.shape
# Out:
# (303, 14)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# ❓Q. What are the datatypes of each column?

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# ❓Q. Are there any missing values or duplicates in the dataset?

# %%
df.isnull().sum()  # Checking missing values
df.duplicated().sum()  # Checking duplicates
# Out:
# 1

# %% [markdown]
# 🔍 Insight:There are no missing values and no duplicates in the dataset.

# %% [markdown]
# ❓Q. How do we handle the categorical columns in the dataset?

# %%
#The dataset has categorical columns like sex, cp, restecg, slope, ca, thal.

#You can encode these columns using techniques like label encoding or one-hot encoding.

df['sex'] = df['sex'].map({0: 'female', 1: 'male'})

# %% [markdown]
# 🔍 Insight: Converting categorical variables to meaningful labels is important for interpretation.

# %% [markdown]
# ❓ Q .What are the summary statistics for numerical features?

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# ❓Q. Are there any inconsistencies or outliers in the dataset?

# %%
#Visualize data using box plots or histograms to detect outliers in numerical features like chol, thalach, trestbps.

sns.boxplot(x='chol', data=df)
# Out:
# <Axes: xlabel='chol'>

# %% [markdown]
# ❓Q. What is the distribution of heart disease (target) in the dataset?

# %%
sns.countplot(x='target', data=df)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %% [markdown]
# 🔍 Insight:The dataset has more people with heart disease (target = 1).

# %% [markdown]
# ❓Q. What is the distribution of age across the dataset?

# %%
sns.histplot(df['age'], kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# 🔍 Insight:Age is fairly distributed, with a slight concentration in the 50s and 60s.

# %% [markdown]
# ❓Q. What is the distribution of cholesterol across the dataset?

# %%
sns.histplot(df['chol'], kde=True)
# Out:
# <Axes: xlabel='chol', ylabel='Count'>

# %% [markdown]
# 🔍 Insight:Cholesterol levels vary significantly, with some patients having very high cholesterol levels

# %% [markdown]
# ❓Q. How does age affect the likelihood of heart disease?

# %%
sns.boxplot(x='target', y='age', data=df)
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %% [markdown]
# 🔍 Insight:Older patients tend to have a higher incidence of heart disease, which is visible in the boxplot.

# %% [markdown]
# ❓Q. What is the distribution of resting blood pressure (trestbps)?

# %%
sns.histplot(df['trestbps'], kde=True)
# Out:
# <Axes: xlabel='trestbps', ylabel='Count'>

# %% [markdown]
# 🔍 Insight:Resting blood pressure is generally within a normal range, with a few extreme values.

# %% [markdown]
# ❓Q. How does maximum heart rate (thalach) vary with heart disease?

# %%
sns.boxplot(x='target', y='thalach', data=df)
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %% [markdown]
# 🔍 Insight:Patients with heart disease tend to have a lower maximum heart rate during exercise.

# %% [markdown]
# ❓Q. What is the distribution of chest pain types (cp)?

# %%
sns.countplot(x='cp', data=df)
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %% [markdown]
# 🔍 Insight:Type 1 chest pain (typical angina) is the most common among those with heart disease.

# %% [markdown]
# ❓Q. What is the relationship between fasting blood sugar and heart disease?

# %%
sns.countplot(x='fbs', hue='target', data=df)
# Out:
# <Axes: xlabel='fbs', ylabel='count'>

# %% [markdown]
# 🔍 Insight:Higher fasting blood sugar (>120 mg/dl) is observed in patients with heart disease.

# %% [markdown]
# ❓Q. Which numerical features are most correlated with the target variable?

# %%
corr_matrix = df.corr(numeric_only= True)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# 🔍 Insight:Age, cholesterol, and thalach are highly correlated with the target variable.

# %% [markdown]
# ❓Q. What is the correlation between cholesterol and resting blood pressure (trestbps)?

# %%
sns.scatterplot(x='chol', y='trestbps', data=df)
# Out:
# <Axes: xlabel='chol', ylabel='trestbps'>

# %% [markdown]
# 🔍 Insight:There seems to be a moderate positive correlation between cholesterol and resting blood pressure.

# %% [markdown]
# ❓Q. What is the relationship between exercise-induced angina (exang) and target?

# %%
sns.countplot(x='exang', hue='target', data=df)
# Out:
# <Axes: xlabel='exang', ylabel='count'>

# %% [markdown]
# 🔍 Insight:Exercise-induced angina is more prevalent among those with heart disease.

# %% [markdown]
# ❓Q. How do slope and ca (vessels) impact heart disease risk?

# %%
sns.countplot(x='slope', hue='target', data=df)
sns.countplot(x='ca', hue='target', data=df)
# Out:
# <Axes: xlabel='slope', ylabel='count'>

# %% [markdown]
# 🔍 Insight:Higher ca (vessels) indicate a greater likelihood of heart disease, and slope affects heart disease prediction.

# %% [markdown]
# ❓Q. What is the age-wise distribution of heart disease by gender?

# %%
sns.histplot(data=df, x='age', hue='target', multiple='stack', kde=True, binwidth=5)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# 🔍 Insight:The distribution shows that men are generally at a higher risk of heart disease at an earlier age than women.

# %% [markdown]
# ❓Q. How do the gender ratios change across age groups?

# %%
sns.histplot(data=df, x='age', hue='sex', multiple='stack', kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# 🔍 Insight:There is a higher concentration of males in heart disease cases, especially in the older age groups.

# %% [markdown]
# ❓Q. What is the distribution of thalassemia (thal) across the dataset?

# %%
sns.countplot(x='thal', data=df)
# Out:
# <Axes: xlabel='thal', ylabel='count'>

# %% [markdown]
# 🔍 Insight:The majority of patients have normal thalassemia (3), but a portion has defects (6 or 7), which could be a contributing factor for heart disease.

# %% [markdown]
# ❓Q. How do different chest pain types relate to heart disease?

# %%
sns.countplot(x='cp', hue='target', data=df)
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %% [markdown]
# 🔍 Insight:Type 1 chest pain (typical angina) is most common in patients with heart disease.

# %% [markdown]
# ❓Q. What key insights did you gather from this analysis that may help in heart disease prediction?
# Answer:
#
# > Age, cholesterol levels, and maximum heart rate (thalach) are significant indicators of heart disease.
#
# > Gender and chest pain type also play vital roles in identifying heart disease patients.
#
# > High blood pressure, high cholesterol, and low maximum heart rate during exercise seem to be major risk factors.

# %% [markdown]
# ❓Q. How do you intend to model this data for heart disease prediction?
#
# Answer:
#
# Using machine learning algorithms like Logistic Regression, Random Forest, and Support Vector Machines will help predict heart disease. The model will be trained on features like age, cholesterol, and maximum heart rate.

# %% [markdown]
# ❓Q. Q25. What steps will you take next after performing the EDA?
#
# Answer:
#
# >Clean and preprocess the data (handle encoding, scaling).
#
# >Split the data into training and testing sets.
#
# >Train models and evaluate performance (using accuracy, AUC, ROC curves).
#
# >Tune hyperparameters to improve model performance.
